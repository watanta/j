# %%
import pandas as pd
import pandas.tseries.offsets as offsets
import os
from sklearn.preprocessing import OneHotEncoder
import pandas_profiling as pdp
from sklearn.preprocessing import LabelEncoder
import japandas as jpd
import jpholiday
import datetime

# %%
train = pd.read_csv("../data/train.csv")
pdp.ProfileReport(train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>3366 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>341.9 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>104.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_broadcasters"><code>broadcasters</code></a> has a high cardinality: 604 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_kick_off_time"><code>kick_off_time</code></a> has a high cardinality: 92 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_match_date"><code>match_date</code></a> has a high cardinality: 599 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_venue"><code>venue</code></a> has a high cardinality: 60 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_attendance">attendance<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>3136</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>

# %%
test = pd.read_csv("../data/test.csv")
pdp.ProfileReport(test)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>477 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.9% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>44.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>96.2 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_broadcasters"><code>broadcasters</code></a> has a high cardinality: 66 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_humidity"><code>humidity</code></a> has 18 / 3.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_match_date"><code>match_date</code></a> has a high cardinality: 95 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_temperature"><code>temperature</code></a> has 18 / 3.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_weather"><code>weather</code></a> has 18 / 3.8% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_away_team">away_team<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>24</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</t

# %%
data = pd.concat((train,test))
data = data.reset_index(drop=True)
print(data.shape)
data.head()
# Out:
# (3843, 13)
#    attendance away_team                                broadcasters home_team  \
# 0     20916.0        浦和                           NHK総合/J SPORTS(録)       G大阪
# 1     14277.0        清水                   山梨放送/テレビ静岡(録)/J SPORTS(録)        甲府
# 2     22531.0        大分                   BS-i/MXテレビ(録)/J SPORTS(録)      FC東京
# 3     28564.0        福岡                                    J SPORTS        磐田
# 4     17199.0       C大阪  スカイパーフェクTV!/NHK名古屋(録)/NHK大阪(録)/J SPORTS(録)       名古屋
#
#    humidity    id kick_off_time  match_date round section  temperature  \
# 0      40.0  9190         16:04  2006-03-04   第1日     第1節          8.3
# 1      28.0  9191         13:00  2006-03-05   第2日     第1節         12.9
# 2      35.0  9192         13:35  2006-03-05   第2日     第1節         12.1
# 3      42.0  9193         14:04  2006-03-05   第2日     第1節         11.6
# 4      32.0  9194         14:04  2006-03-05   第2日     第1節         13.1
#
#               venue weather
# 0           万博記念競技場       晴
# 1  山梨県小瀬スポーツ公園陸上競技場       晴
# 2          味の素スタジアム       晴
# 3        静岡スタジアムエコパ       晴
# 4       名古屋市瑞穂陸上競技場       晴

# %%
#表記ゆれ統一
data["away_team"] = data["away_team"].str.h2z()
data["home_team"] = data["home_team"].str.h2z()

# %%
set(test["venue"])-set(train["venue"])
# Out:
# {'トランスコスモススタジアム長崎', 'パナソニックスタジアム吹田', '三協フロンテア柏スタジアム'}

# %%
stadium = pd.read_csv("..\\data/stadium_capacity_mapping.csv")
print(stadium.shape)
stadium.head()
# Out:
# (99, 2)
#        stadium  capacity
# 0      日産スタジアム     72081
# 1  埼玉スタジアム2002     62010
# 2        国立競技場     54224
# 3   静岡スタジアムエコパ     51697
# 4     エコパスタジアム     51697

# %%
match = pd.read_csv("..\\data/match_reports.csv")
print(match.shape)
match.head()
# Out:
# (3825, 25)
#      id home_team_player11 home_team_player10 home_team_player9  \
# 0  9190      9 マグノ アウベス FW     8 フェルナンジーニョ FW       10 二川 孝広 MF
# 1  9191       18 長谷川 太郎 FW          16 バレー FW       11 宇留野 純 FW
# 2  9192          9 ルーカス FW     21 ササ サルセード FW       35 リチェーリ FW
# 3  9193        15 西野 泰正 FW     22 カレン ロバート FW         7 名波 浩 MF
# 4  9194        19 杉本 恵太 FW        11 玉田 圭司 FW       27 片山 奨典 MF
#
#   home_team_player8 home_team_player7 home_team_player6 home_team_player5  \
# 0        7 遠藤 保仁 MF       27 橋本 英郎 MF       17 明神 智和 MF       14 家長 昭博 DF
# 1       31 林 健太郎 MF       25 鈴木 健太 MF        8 倉貫 一毅 MF        4 山本 英臣 DF
# 2        6 今野 泰幸 MF       23 梶山 陽平 MF      19 伊野波 雅彦 MF       15 鈴木 規郎 DF
# 3       14 村井 慎二 MF       23 福西 崇史 MF      25 ファブリシオ MF        11 西 紀寛 MF
# 4        7 中村 直志 MF       14 吉村 圭司 MF         8 金 正友 MF        6 有村 光史 DF
#
#   home_team_player4 home_team_player3        ...         away_team_player2  \
# 0         6 山口 智 DF        2 シジクレイ DF        ...                2 坪井 慶介 DF
# 1         20 ビジュ DF       15 アライール DF        ...               25 市川 大祐 DF
# 2        5 増嶋 竜也 DF        2 茂庭 照幸 DF        ...                2 三木 隆司 DF
# 3        6 服部 年宏 DF         5 田中 誠 DF        ...               22 中村 北斗 DF
# 4       29 深津 康太 DF        5 古賀 正紘 DF        ...           2 ブルーノ クアドロス DF
#
#   away_team_player3  away_team_player4  away_team_player5 away_team_player6  \
# 0   4 田中 マルクス闘莉王 DF        20 堀之内 聖 DF         6 山田 暢久 MF       17 長谷部 誠 MF
# 1       26 青山 直晃 DF         4 高木 和道 DF         3 山西 尊裕 DF       13 兵働 昭弘 MF
# 2        4 深谷 友基 DF        22 上本 大海 DF        5 エジミウソン MF       11 トゥーリオ MF
# 3        4 金古 聖司 DF        5 千代反田 充 DF         3 アレックス DF        7 宮崎 光平 MF
# 4        5 前田 和哉 DF         3 柳本 啓成 DF         4 河村 崇大 MF       23 下村 東美 MF
#
#   away_team_player7 away_team_player8 away_team_player9 away_team_player10  \
# 0       13 鈴木 啓太 MF   8 三都主 アレサンドロ MF       18 小野 伸二 MF          10 ポンテ FW
# 1        7 伊東 輝悦 MF       16 枝村 匠馬 MF       10 藤本 淳吾 MF      18 チョ ジェジン FW
# 2        6 梅田 高志 MF       17 根本 裕一 MF       26 内村 圭宏 MF        13 高松 大樹 FW
# 3        6 布部 陽功 MF         8 ホベルト MF       14 古賀 誠史 MF        27 田中 佑昌 FW
# 4         10 ピンゴ MF       6 ゼ カルロス MF        8 森島 寛晃 FW        20 西澤 明訓 FW
#
#   away_team_player11
# 0        21 ワシントン FW
# 1      17 マルキーニョス FW
# 2         9 オズマール FW
# 3        36 グラウシオ FW
# 4         9 古橋 達弥 FW
#
# [5 rows x 25 columns]

# %%
holiday = pd.read_csv("..\\data/holidays_in_japan.csv")
print(holiday.shape)
holiday.head()
# Out:
# (242, 2)
#   holiday_date              description
# 0   2006-01-01            New Years Day
# 1   2006-01-02        New Years Holiday
# 2   2006-01-03        New Years Holiday
# 3   2006-01-09        Coming-of-age Day
# 4   2006-02-11  National Foundation Day

# %% [markdown]
# # team labelencoder

# %%
team_df  = data.loc[:,["home_team","away_team"]]

# %%
le = LabelEncoder()
hometeam_label = le.fit_transform(team_df["home_team"])
hometeam_label
# Out:
# array([29, 20, 28, ...,  3, 22, 24], dtype=int64)

# %%
hometeam_label_df = pd.DataFrame(hometeam_label)
hometeam_label_df.columns = ["hometeam_label"]

# %%
awayteam_label = le.transform(team_df["away_team"])
awayteam_label
# Out:
# array([17, 18,  4, ..., 19,  1, 18], dtype=int64)

# %%
awayteam_label_df = pd.DataFrame(awayteam_label)
awayteam_label_df.columns = ["awayteam_label"]

# %%
feature = data[["id","match_date","attendance"]]
feature = pd.concat((feature,hometeam_label_df),axis = 1)
feature = pd.concat((feature,awayteam_label_df),axis = 1)
print(feature.shape)
feature.columns = ["id","date","attendance","hometeam_label","awayteam_label"]

display(feature)
feature.to_csv("../data/team.csv", index=False)
# Out:
# (3843, 5)
#          id        date  attendance  hometeam_label  awayteam_label
# 0      9190  2006-03-04     20916.0              29              17
# 1      9191  2006-03-05     14277.0              20              18
# 2      9192  2006-03-05     22531.0              28               4
# 3      9193  2006-03-05     28564.0              21              23
# 4      9194  2006-03-05     17199.0               3              27
# 5      9195  2006-03-05     13085.0               5               2
# 6      9196  2006-03-05     17444.0               7              10
# 7      9197  2006-03-05     17564.0               8              26
# 8      9198  2006-03-05     23607.0              16               0
# 9      9199  2006-03-11     56512.0              17              21
# 10     9200  2006-03-11     11896.0               2              20
# 11     9201  2006-03-11     40266.0              10              28
# 12     9202  2006-03-11     13054.0              18               3
# 13     9203  2006-03-11     22454.0              26              16
# 14     9204  2006-03-11      7921.0               0               7
# 15     9205  2006-03-11     12040.0              23               5
# 16     9206  2006-03-12     17043.0               4               8
# 17     9207  2006-03-12     30561.0              27              29
# 18     9208  2006-03-18     19011.0              28              18
# 19     9209  2006-03-18     10560.0              21               0
# 20     9210  2006-03-18     16742.0               8              17
# 21     9211  2006-03-18      9368.0               5              10
# 22     9212  2006-03-18      9082.0              20               7
# 23     9213  2006-03-18     22651.0               3              26
# 24     9214  2006-03-18      8567.0               2              23
# 25     9215  2006-03-18     19307.0              16              27
# 26     9216  2006-03-18      8388.0              29               4
# 27     9217  2006-03-21     14815.0              26              20
# 28     9218  2006-03-21      8585.0              23               3
# 29     9219  2006-03-21     43815.0              17              27
# ...     ...         ...         ...             ...             ...
# 3813  20886  2018-07-18         NaN               8              29
# 3814  20887  2018-07-18         NaN              24              22
# 3815  20888  2018-07-18         NaN              17               3
# 3816  20889  2018-07-22         NaN               3               8
# 3817  20890  2018-07-22         NaN              22              19
# 3818  20891  2018-07-22         NaN              26              14
# 3819  20892  2018-07-22         NaN              11              21
# 3820  20893  2018-07-22         NaN              28              16
# 3821  20894  2018-07-22         NaN               7              24
# 3822  20895  2018-07-22         NaN              29              18
# 3823  20896  2018-07-22         NaN              27              17
# 3824  20897  2018-07-22         NaN              25               1
# 3825  30000  2018-11-24         NaN               1              26
# 3826  30001  2018-11-24         NaN              28               7
# 3827  30002  2018-11-24         NaN              19              17
# 3828  30003  2018-11-24         NaN              18              22
# 3829  30004  2018-11-24         NaN              21              11
# 3830  30005  2018-11-24         NaN              29              24
# 3831  30006  2018-11-24         NaN              27              14
# 3832  30007  2018-11-24         NaN               8               3
# 3833  30008  2018-11-24         NaN              25              16
# 3834  30009  2018-12-01         NaN              11               8
# 3835  30010  2018-12-01         NaN              26              25
# 3836  30011  2018-12-01         NaN              17              28
# 3837  30012  2018-12-01         NaN              14              29
# 3838  30013  2018-12-01         NaN               7              21
# 3839  30014  2018-12-01         NaN              16              27
# 3840  30015  2018-12-01         NaN               3              19
# 3841  30016  2018-12-01         NaN              22               1
# 3842  30017  2018-12-01         NaN              24              18
#
# [3843 rows x 5 columns]

# %%
pd.DataFrame(le.classes_).to_csv("../data/team_label.csv", index=False)

# %%
le.classes_
# Out:
# array(['京都', '仙台', '千葉', '名古屋', '大分', '大宮', '山形', '川崎Ｆ', '広島', '徳島', '新潟',
#        '札幌', '東京Ｖ', '松本', '柏', '横浜ＦＣ', '横浜ＦＭ', '浦和', '清水', '湘南', '甲府',
#        '磐田', '神戸', '福岡', '長崎', '鳥栖', '鹿島', 'Ｃ大阪', 'ＦＣ東京', 'Ｇ大阪'],
#       dtype=object)

# %% [markdown]
# # 休日ラベル

# %%
date = pd.date_range(start='2006-1-1', end='2018-12-31', freq='D')
date = pd.Series(date)

# %%
public_holiday = []
for i, d in date.iteritems():
    public_holiday.append(jpholiday.is_holiday(datetime.date(d.to_datetime().year,d.to_datetime().month,d.to_datetime().day)))

date_df = pd.DataFrame(date)
date_df.columns = ["date"]
p_holiday = pd.DataFrame(public_holiday)
p_holiday.columns = ["public_holiday"]

p_holiday_df = pd.concat((date_df,p_holiday),axis=1)
p_holiday_df["public_holiday"] = p_holiday_df["public_holiday"].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: FutureWarning: to_datetime is deprecated. Use self.to_pydatetime()
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
p_holiday_df
# Out:
#            date  public_holiday
# 0    2006-01-01               1
# 1    2006-01-02               1
# 2    2006-01-03               0
# 3    2006-01-04               0
# 4    2006-01-05               0
# 5    2006-01-06               0
# 6    2006-01-07               0
# 7    2006-01-08               0
# 8    2006-01-09               1
# 9    2006-01-10               0
# 10   2006-01-11               0
# 11   2006-01-12               0
# 12   2006-01-13               0
# 13   2006-01-14               0
# 14   2006-01-15               0
# 15   2006-01-16               0
# 16   2006-01-17               0
# 17   2006-01-18               0
# 18   2006-01-19               0
# 19   2006-01-20               0
# 20   2006-01-21               0
# 21   2006-01-22               0
# 22   2006-01-23               0
# 23   2006-01-24               0
# 24   2006-01-25               0
# 25   2006-01-26               0
# 26   2006-01-27               0
# 27   2006-01-28               0
# 28   2006-01-29               0
# 29   2006-01-30               0
# ...         ...             ...
# 4718 2018-12-02               0
# 4719 2018-12-03               0
# 4720 2018-12-04               0
# 4721 2018-12-05               0
# 4722 2018-12-06               0
# 4723 2018-12-07               0
# 4724 2018-12-08               0
# 4725 2018-12-09               0
# 4726 2018-12-10               0
# 4727 2018-12-11               0
# 4728 2018-12-12               0
# 4729 2018-12-13               0
# 4730 2018-12-14               0
# 4731 2018-12-15               0
# 4732 2018-12-16               0
# 4733 2018-12-17               0
# 4734 2018-12-18               0
# 4735 2018-12-19               0
# 4736 2018-12-20               0
# 4737 2018-12-21               0
# 4738 2018-12-22               0
# 4739 2018-12-23               1
# 4740 2018-12-24               1
# 4741 2018-12-25               0
# 4742 2018-12-26               0
# 4743 2018-12-27               0
# 4744 2018-12-28               0
# 4745 2018-12-29               0
# 4746 2018-12-30               0
# 4747 2018-12-31               0
#
# [4748 rows x 2 columns]

# %%
weekday = []
for d in date:
    weekday.append(d.weekday())
    
weekday_df = pd.DataFrame(weekday)
weekday_df.columns = ["weekday"]
data = pd.concat((p_holiday_df,weekday_df),axis=1)

# %%
data.loc[(data["weekday"]==5),"holiday"] = True
data.loc[(data["weekday"]==6),"holiday"] = True

data = data.fillna(False)
data["holiday"] = data["holiday"].astype(int)
data["or_holiday"] = (data["public_holiday"]) | (data["holiday"])
print(data.shape)
data.head()
# Out:
# (4748, 5)
#         date  public_holiday  weekday  holiday  or_holiday
# 0 2006-01-01               1        6        1           1
# 1 2006-01-02               1        0        0           1
# 2 2006-01-03               0        1        0           0
# 3 2006-01-04               0        2        0           0
# 4 2006-01-05               0        3        0           0

# %%
data.to_csv("../data/holiday.csv", index=False)

# %% [markdown]
# # キックオフ時刻encoder

# %%
kickoff = data.loc[:,["id","kick_off_time"]]
kickoff["kick_off_time"] = pd.to_datetime(kickoff["kick_off_time"])
print(kickoff.shape)
kickoff.head()
# Out:
# (3843, 2)
#      id       kick_off_time
# 0  9190 2018-11-02 16:04:00
# 1  9191 2018-11-02 13:00:00
# 2  9192 2018-11-02 13:35:00
# 3  9193 2018-11-02 14:04:00
# 4  9194 2018-11-02 14:04:00

# %%
kickoff["kick_off_time_hour"] = kickoff["kick_off_time"].apply(lambda x: x.round("H"))
kickoff["kick_off_time_hour"] = kickoff["kick_off_time_hour"].apply(lambda x: x.hour)

# %%
kickoff.head()
# Out:
#      id       kick_off_time  kick_off_time_hour
# 0  9190 2018-11-02 16:04:00                  16
# 1  9191 2018-11-02 13:00:00                  13
# 2  9192 2018-11-02 13:35:00                  14
# 3  9193 2018-11-02 14:04:00                  14
# 4  9194 2018-11-02 14:04:00                  14

# %%
le = LabelEncoder()
kickoff_label = le.fit_transform(kickoff["kick_off_time_hour"])
kickoff_label
# Out:
# array([3, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
kickoff["kickoff_hour_label"] =  kickoff_label
kickoff.head()
# Out:
#      id       kick_off_time  kick_off_time_hour  kickoff_hour_label
# 0  9190 2018-11-02 16:04:00                  16                   3
# 1  9191 2018-11-02 13:00:00                  13                   0
# 2  9192 2018-11-02 13:35:00                  14                   1
# 3  9193 2018-11-02 14:04:00                  14                   1
# 4  9194 2018-11-02 14:04:00                  14                   1

# %%
kickoff.to_csv("../data/kickoff.csv",index=False)

# %%
pd.DataFrame(le.classes_).to_csv("../data/kickoff_label.csv", index=False)
le.classes_
# Out:
# array([13, 14, 15, 16, 17, 18, 19, 20], dtype=int64)

# %% [markdown]
# # スタジアム

# %%
stadiam = data[["id", "venue"]]
stadiam.head()
# Out:
#      id             venue
# 0  9190           万博記念競技場
# 1  9191  山梨県小瀬スポーツ公園陸上競技場
# 2  9192          味の素スタジアム
# 3  9193        静岡スタジアムエコパ
# 4  9194       名古屋市瑞穂陸上競技場

# %%
stadiam_capa = pd.read_csv("..\\data/stadium_capacity_mapping.csv")
stadiam_capa.columns=["venue","capacity"]
stadiam_capa.head()
# Out:
#          venue  capacity
# 0      日産スタジアム     72081
# 1  埼玉スタジアム2002     62010
# 2        国立競技場     54224
# 3   静岡スタジアムエコパ     51697
# 4     エコパスタジアム     51697

# %%
total_stadiam = pd.merge(stadiam,stadiam_capa,on="venue",how="left")
le = LabelEncoder()
stadiam_label = le.fit_transform(total_stadiam["venue"])
stadiam_label
# Out:
# array([23, 38, 30, ..., 15, 13, 11], dtype=int64)

# %%
total_stadiam["stadiam_label"] = stadiam_label
total_stadiam.head()
# Out:
#      id             venue  capacity  stadiam_label
# 0  9190           万博記念競技場     21000             23
# 1  9191  山梨県小瀬スポーツ公園陸上競技場     15859             38
# 2  9192          味の素スタジアム     48999             30
# 3  9193        静岡スタジアムエコパ     51697             60
# 4  9194       名古屋市瑞穂陸上競技場     20223             29

# %%
total_stadiam.to_csv("../data/stadiam.csv", index=False)

# %%
pd.DataFrame(le.classes_).to_csv("../data/stadiam_label.csv", index=False)
le.classes_
# Out:
# array(['IAIスタジアム日本平', 'NACK5スタジアム大宮', 'NDソフトスタジアム山形', 'ShonanBMWスタジアム平塚',
#        'さいたま市浦和駒場スタジアム', 'アウトソーシングスタジアム日本平', 'エコパスタジアム', 'エディオンスタジアム広島',
#        'キンチョウスタジアム', 'コカ・コーラウエスト広島スタジアム', 'デンカビッグスワンスタジアム',
#        'トランスコスモススタジアム長崎', 'ニッパツ三ツ沢球技場', 'ノエビアスタジアム神戸', 'パナソニックスタジアム吹田',
#        'パロマ瑞穂スタジアム', 'フクダ電子アリーナ', 'ベストアメニティスタジアム', 'ホームズスタジアム神戸',
#        'ヤマハスタジアム(磐田)', 'ヤンマースタジアム長居', 'ユアテックスタジアム仙台', 'レベルファイブスタジアム',
#        '万博記念競技場', '三協フロンテア柏スタジアム', '九州石油ドーム', '京都市西京極総合運動公園陸上競技場兼球技場',
#        '佐賀県総合運動場陸上競技場', '名古屋市瑞穂球技場', '名古屋市瑞穂陸上競技場', '味の素スタジアム', '国立競技場',
#        '埼玉スタジアム2002', '大分銀行ドーム', '大阪長居スタジアム', '大阪長居第2陸上競技場', '宮城スタジアム',
#        '山梨中銀スタジアム', '山梨県小瀬スポーツ公園陸上競技場', '市立吹田サッカースタジアム', '平塚競技場',
#        '広島ビッグアーチ', '新潟スタジアム', '日本平スタジアム', '日産スタジアム', '日立柏サッカー場', '札幌ドーム',
#        '札幌厚別公園競技場', '東北電力ビッグスワンスタジアム', '東平尾公園博多の森球技場', '松本平広域公園総合球技場',
#        '柏の葉公園総合競技場', '横浜市三ツ沢公園球技場', '熊本県民総合運動公園陸上競技場', '熊谷スポーツ文化公園陸上競技場',
#        '県立カシマサッカースタジアム', '石川県西部緑地公園陸上競技場', '神戸総合運動公園ユニバー記念競技場',
#        '等々力陸上競技場', '豊田スタジアム', '静岡スタジアムエコパ', '鳴門・大塚スポーツパークポカリスエットスタジアム',
#        '鹿児島県立鴨池陸上競技場'], dtype=object)

# %% [markdown]
# # month

# %%
data["match_date"] = pd.to_datetime(data["match_date"])

# %%
data["match_date_month"] = data["match_date"].dt.month

# %%
month = data.loc[:,["id","match_date_month"]]

# %%
month.head()
# Out:
#      id  match_date_month
# 0  9190                 3
# 1  9191                 3
# 2  9192                 3
# 3  9193                 3
# 4  9194                 3

# %%
month.to_csv("../data/month.csv", index=False)

# %% [markdown]
# # チームラベル+休日フラグ+kickofftimeラベル+stadium_capa+month

# %%
team = pd.read_csv("../data/team.csv")
holiday = pd.read_csv("../data/holiday.csv")
kickoff = pd.read_csv("../data/kickoff.csv")
stadiam = pd.read_csv("../data/stadiam.csv")
month = pd.read_csv("../data/month.csv")

# %%
feature = pd.merge(team,holiday,on="date",how="left")
feature = pd.merge(feature,kickoff,on="id",how="left")
feature = pd.merge(feature,stadiam,on="id",how="left")
feature = pd.merge(feature,month,on="id",how="left")
display(feature)
feature.to_csv("../data/feature.csv", index=False)
# Out:
#          id        date  attendance  hometeam_label  awayteam_label  \
# 0      9190  2006-03-04     20916.0              29              17
# 1      9191  2006-03-05     14277.0              20              18
# 2      9192  2006-03-05     22531.0              28               4
# 3      9193  2006-03-05     28564.0              21              23
# 4      9194  2006-03-05     17199.0               3              27
# 5      9195  2006-03-05     13085.0               5               2
# 6      9196  2006-03-05     17444.0               7              10
# 7      9197  2006-03-05     17564.0               8              26
# 8      9198  2006-03-05     23607.0              16               0
# 9      9199  2006-03-11     56512.0              17              21
# 10     9200  2006-03-11     11896.0               2              20
# 11     9201  2006-03-11     40266.0              10              28
# 12     9202  2006-03-11     13054.0              18               3
# 13     9203  2006-03-11     22454.0              26              16
# 14     9204  2006-03-11      7921.0               0               7
# 15     9205  2006-03-11     12040.0              23               5
# 16     9206  2006-03-12     17043.0               4               8
# 17     9207  2006-03-12     30561.0              27              29
# 18     9208  2006-03-18     19011.0              28              18
# 19     9209  2006-03-18     10560.0              21               0
# 20     9210  2006-03-18     16742.0               8              17
# 21     9211  2006-03-18      9368.0               5              10
# 22     9212  2006-03-18      9082.0              20               7
# 23     9213  2006-03-18     22651.0               3              26
# 24     9214  2006-03-18      8567.0               2              23
# 25     9215  2006-03-18     19307.0              16              27
# 26     9216  2006-03-18      8388.0              29               4
# 27     9217  2006-03-21     14815.0              26              20
# 26                    19                   6                万博記念競技場     21000
# 27                    14                   1         県立カシマサッカースタジアム     37496
# 28                    14                   1           東平尾公園博多の森球技場     22331
# 29                    15                   2            埼玉スタジアム2002     62010
# ...                  ...                 ...                    ...       ...
# 3813                  19                   6           エディオンスタジアム広島     36894
# 3814                  19                   6        トランスコスモススタジアム長崎     20258
# 3815                  20                   7            埼玉スタジアム2002     62010
# 3816                  18                   5                豊田スタジアム     41255
# 3817                  18                   5            ノエビアスタジアム神戸     28425
# 3818                  19                   6         県立カシマサッカースタジアム     37496
# 3819                  19                   6              札幌厚別公園競技場     19620
# 3820                  19                   6               味の素スタジアム     48999
# 3821                  19                   6               等々力陸上競技場     26827
# 3822                  19                   6          パナソニックスタジアム吹田     39694
# 3823                  19                   6            ヤンマースタジアム長居     47853
# 3824                  19                   6          ベストアメニティスタジアム     24130
# 3825                  14                   1           ユアテックスタジアム仙台     19694
# 3826                  14                   1               味の素スタジアム     48999
# 3827                  14                   1       ShonanBMWスタジアム平塚     15732
# 3828                  14                   1            IAIスタジアム日本平     20248
# 3829                  14                   1           ヤマハスタジアム(磐田)     15165
# 3830                  14                   1          パナソニックスタジアム吹田     39694
# 3831                  14                   1            ヤンマースタジアム長居     47853
# 3832                  14                   1           エディオンスタジアム広島     36894
# 3833                  14                   1          ベストアメニティスタジアム     24130
# 3834                  14                   1                  札幌ドーム     39856
# 3835                  14                   1         県立カシマサッカースタジアム     37496
# 3836                  14                   1            埼玉スタジアム2002     62010
# 3837                  14                   1          三協フロンテア柏スタジアム     15109
# 3838                  14                   1               等々力陸上競技場     26827
# 3839                  14                   1                日産スタジアム     72081
# 3840                  14                   1             パロマ瑞穂スタジアム     20223
# 3841                  14                   1            ノエビアスタジアム神戸     28425
# 3842                  14                   1        トランスコスモススタジアム長崎     20258
#
#       stadiam_label  match_date_month
# 0                23                 3
# 1                38                 3
# 2                30                 3
# 3                60                 3
# 4                29                 3
# 5                32                 3
# 6                58                 3
# 7                41                 3
# 8                44                 3
# 9                32                 3
# 10               16                 3
# 11               42                 3
# 12               43                 3
# 13               55                 3
# 14               26                 3
# 15               49                 3
# 16               25                 3
# 17               34                 3
# 18               30                 3
# 19               19                 3
# 20               41                 3
# 21               32                 3
# 22               38                 3
# 23               59                 3
# 24               16                 3
# 25               44                 3
# 26               23                 3
# 27               55                 3
# 28               49                 3
# 29               32                 3
# ...             ...               ...
# 3813              7                 7
# 3814             11                 7
# 3815             32                 7
# 3816             59                 7
# 3817             13                 7
# 3818             55                 7
# 3819             47                 7
# 3820             30                 7
# 3821             58                 7
# 3822             14                 7
# 3823             20                 7
# 3824             17                 7
# 3825             21                11
# 3826             30                11
# 3827              3                11
# 3828              0                11
# 3829             19                11
# 3830             14                11
# 3831             20                11
# 3832              7                11
# 3833             17                11
# 3834             46                12
# 3835             55                12
# 3836             32                12
# 3837             24                12
# 3838             58                12
# 3839             44                12
# 3840             15                12
# 3841             13                12
# 3842             11                12
#
# [3843 rows x 16 columns]
